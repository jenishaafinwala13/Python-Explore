# %%
print("hello world")
# Out:
# hello world

# %%
f1=open("student.txt","w")
f1.write("i am a boy")
f1.write("i and my friends play together")
# Out:
# 30

# %%
f1.close(

)

# %%
f2=open("student.txt","r+")
lines=f2.readline()
tw="boy"
twC=0
tw1="and"
tw1C=0
while lines:
 # print(lines)
  words=lines.split()
  for i in words :
    if (i==tw):
     twC+=1
    elif (i==tw1):
     tw1C+=1
  lines = f2.readline()
print (twC,tw1C)
# Out:
# 2 2

# %%
emp = []
emp.append("hjh")
emp.append("jhjk")
print (emp)
emp.append("hgd")
print(emp)
# Out:
# ['hjh', 'jhjk']
# ['hjh', 'jhjk', 'hgd']

# %%
# Stack Creation
def create_stack():
    stack = list()            #declaring an empty list
    return stack

# Checking for empty stack
def Isempty(stack):
    return len(stack) == 0

# Inserting items into the stack
def push(stack, n):
    stack.append(n)
    print("pushed item: " + n)

# Removal of an element from the stack
def pop(stack):
    if (Isempty(stack)):
        return "stack is empty"
    else:
        return stack.pop()

# Displaying the stack elements
def show(stack):
    print("The stack elements are:")
    for i in stack:
        print(i)

emp = create_stack()
push(emp, "kamal")
push(emp, "rajat")
push(emp, "rajat1")
print("popped item: " + pop(emp))
push(emp, "nil")
show(emp)
# Out:
# pushed item: kamal
# pushed item: rajat
# pushed item: rajat1
# popped item: rajat1
# pushed item: nil
# The stack elements are:
# kamal
# rajat
# nil
