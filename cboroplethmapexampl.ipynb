# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/fips-unemp-16.csv",
                   dtype={"fips": str})

import plotly.express as px

fig = px.choropleth(df, geojson=counties, locations='fips', color='unemp',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           scope="usa",
                           labels={'unemp':'unemployment rate'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # New Section

# %%
import json
import pandas as pd

# !pip install plotly


import plotly.express as px
import plotly.io as pio

india_states=json.load(open("/content/drive/MyDrive/Colab Notebooks/states_india.geojson", 'r'))

# %%
india_states
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
state_id_map = {}
for feature in india_states['features']:
  feature['id'] = feature['properties']['state_code']
  #print(feature['id'])
  state_id_map[feature['properties']['st_nm']] = feature['id']

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/india_states.csv")

df['Density']=df['Density[a]'].apply(lambda x: int(float(x.split("/")[0].replace(",",""))))

df['State or union territory']

df['id'] = df['State or union territory'].apply(lambda x: state_id_map[x])



fig = px.choropleth(df, locations='id', geojson='india_states', color='Density')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
