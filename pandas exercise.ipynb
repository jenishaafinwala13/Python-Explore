# %%
print("hello",2,"bye")
# Out:
# hello 2 bye

# %%
age=25
if age>18:
  print('You are eligible for vote')
# Out:
# You are eligible for vote

# %%
import pandas as pd

# %%
import requests

url = "https://finance.yahoo.com/crypto"
headers = {'User-Agent': 'Mozilla/5.0'}

response = requests.get(url, headers=headers)
dfs = pd.read_html(response.text)

# %%
dfs
# Out:
# [          Symbol                 Name  Price (Intraday)        Change  \
#  0        BTC-USD          Bitcoin USD      29498.940000 -2.751500e+02
#  1        ETH-USD         Ethereum USD       1850.090000 -8.780000e+00
#  2       USDT-USD      Tether USDt USD          0.998889 -7.320000e-04
#  3        BNB-USD              BNB USD        242.050000 -2.600000e+00
#  4        XRP-USD              XRP USD          0.628894 -1.422200e-02
#  5       USDC-USD         USD Coin USD          0.999852 -2.460000e-04
#  6      STETH-USD  Lido Staked ETH USD       1845.370000 -1.123000e+01
#  7       DOGE-USD         Dogecoin USD          0.075402  1.700000e-05
#  8        ADA-USD          Cardano USD          0.297907 -9.560000e-04
#  9        SOL-USD           Solana USD         24.350000 -2.300000e-01
#  10      WTRX-USD     Wrapped TRON USD          0.076794 -1.540000e-04
#  11       TRX-USD             TRON USD          0.077016  1.750000e-04
#  12     MATIC-USD          Polygon USD          0.686373 -4.788000e-03
#  13       LTC-USD         Litecoin USD         83.770000 -2.100000e-01
#  14       DOT-USD         Polkadot USD          5.008200 -3.800000e-02
#  15      SHIB-USD        Shiba Inu USD          0.000010 -1.100000e-07
#  16       DAI-USD              Dai USD          0.999757  1.680000e-04
#  17      WBTC-USD  Wrapped Bitcoin USD      29499.960000 -2.726400e+02
#  18       BCH-USD     Bitcoin Cash USD        233.930000 -2.870000e+00
#  19  TON11419-USD          Toncoin USD          1.263200 -2.850000e-02
#  20      AVAX-USD        Avalanche USD         12.500000 -1.500000e-01
#  21      LINK-USD        Chainlink USD          7.602300  7.590000e-02
#  22       XLM-USD          Stellar USD          0.139280 -3.023000e-03
#  23       LEO-USD     UNUS SED LEO USD          4.010000 -4.200000e-03
#  24   UNI7083-USD          Uniswap USD          6.236400  9.560000e-02
#
#     % Change Market Cap Volume in Currency (Since 0:00 UTC)  \
#  0    -0.92%   573.845B                             14.295B
#  1    -0.47%   222.292B                              4.304B
#  2    -0.07%     83.44B                             21.677B
#  3    -1.06%     37.24B                            383.788M
#  4    -2.21%    33.169B                              1.745B
#  5    -0.02%    26.251B                              3.168B
#  6    -0.61%    14.812B                              6.967M
#  7    +0.02%    10.596B                            337.954M
#  8    -0.32%    10.435B                            214.062M
#  9    -0.95%     9.882B                            417.924M
#  10   -0.20%     7.808B                              724253
#  11   +0.23%     6.894B                            173.561M
#  12   -0.69%     6.397B                             257.95M
#  13   -0.25%     6.159B                            307.031M
#  14   -0.75%      6.08B                             91.075M
#  15   -1.08%     5.776B                            318.235M
#  16   +0.02%     5.183B                             95.235M
#  17   -0.92%     4.785B                            133.094M
#  18   -1.21%     4.555B                            272.526M
#  19   -2.21%     4.335B                              25.99M
#  20   -1.18%     4.299B                            107.093M
#  21   +1.01%     4.091B                            338.249M
#  22   -2.12%     3.812B                            131.988M
#  23   -0.10%     3.728B                              1.797M
#  24   +1.56%     3.602B                            102.546M
#
#     Volume in Currency (24Hr) Total Volume All Currencies (24Hr)  \
#  0                    14.295B                            14.295B
#  1                     4.304B                             4.304B
#  2                    21.677B                            21.677B
#  3                   383.788M                           383.788M
#  4                     1.745B                             1.745B
#  5                     3.168B                             3.168B
#  6                     6.967M                             6.967M
#  7                   337.954M                           337.954M
#  8                   214.062M                           214.062M
#  9                   417.924M                           417.924M
#  10                    724253                             724253
#  11                  173.561M                           173.561M
#  12                   257.95M                            257.95M
#  13                  307.031M                           307.031M
#  14                   91.075M                            91.075M
#  15                  318.235M                           318.235M
#  16                   95.235M                            95.235M
#  17                  133.094M                           133.094M
#  18                  272.526M                           272.526M
#  19                    25.99M                             25.99M
#  20                  107.093M                           107.093M
#  21                  338.249M                           338.249M
#  22                  131.988M                           131.988M
#  23                    1.797M                             1.797M
#  24                  102.546M                           102.546M
#
#     Circulating Supply  52 Week Range  Day Chart
#  0             19.453M            NaN        NaN
#  1            120.152M            NaN        NaN
#  2             83.533B            NaN        NaN
#  3            153.853M            NaN        NaN
#  4             52.741B            NaN        NaN
#  5             26.255B            NaN        NaN
#  6              8.027M            NaN        NaN
#  7             140.53B            NaN        NaN
#  8             35.028B            NaN        NaN
#  9            405.782M            NaN        NaN
#  10           101.676B            NaN        NaN
#  11            89.514B            NaN        NaN
#  12             9.319B            NaN        NaN
#  13            73.525M            NaN        NaN
#  14             1.214B            NaN        NaN
#  15           589.347T            NaN        NaN
#  16             5.184B            NaN        NaN
#  17             162205            NaN        NaN
#  18            19.472M            NaN        NaN
#  19             3.432B            NaN        NaN
#  20           343.811M            NaN        NaN
#  21             538.1M            NaN        NaN
#  22            27.368B            NaN        NaN
#  23           929.661M            NaN        NaN
#  24           577.501M            NaN        NaN  ]
